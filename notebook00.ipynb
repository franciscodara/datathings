# %% [markdown]
# # PySpark begins

# %%
print ("Hello world!")

# %%
display(dbutils.fs.ls("/databricks-datasets"))

# %%
arquivo = "dbfs:/databricks-datasets/flights/"

# %%
arquivo

# %%
df = spark\
.read.format("csv")\
.option("inferSchema", "True")\
.option("header", "True")\
.csv(arquivo)

# %%
df.printSchema()

# %%
type(df)

# %%
df.take(10)

# %%
display(df.show(10))

# %%
df.count()

# %%
from pyspark.sql.functions import max
df.select(max("delay")).take(2)

# %%
df.filter ("delay < 2").show(2)

# %%
df.where ("delay < 2").show(2)

# %%
df.sort("delay").show(5)

# %%
from pyspark.sql.functions import desc, asc, expr
df.orderBy (expr("delay desc")).show(10)

# %%
df.describe().show()

# %%
df.show()

# %%
for i in df.collect():
    print (1)
    print (i[0], i[1] *2)

# %%
df = df.withColumn("NovaColuna", df["delay"]+2)
df.show(10)

# %%
df.withColumnRenamed('NovaColuna', 'NewColumn').show()

# %%
df = df.drop("NovaColuna")
df.show(10)

# %%
df.filter('delay is null').show(5)

# %%
df.filter(df.delay.isNull()).show(10)

# %%
df.filter(df.delay.isNotNull()).show(10)

# %%
df.na.fill(value=0).show()

# %%
df.na.fill(value=0, subset=['delay']).show()

# %%
df.na.fill('').show()

# %%
df.na.drop().show()
